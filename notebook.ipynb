# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Lab_Histogram')

# %%
# !nvidia-smi
# Out:
# Tue Apr 22 08:21:37 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# !nvcc -arch=sm_75 -o histogram main.cu kernel.cu support.cu

# %%
# !./histogram
# Out:
# Setting up the problem...0.027418 s
#     Input size = 1000000
#     Number of bins = 4096
# Allocating device variables...0.244691 s
# Copying data from host to device...0.003378 s
# Launching kernel...0.000569 s
# Verifying results...TEST PASSED

# %%
# !./histogram 50000
# Out:
# Setting up the problem...0.001267 s
#     Input size = 50000
#     Number of bins = 4096
# Allocating device variables...0.224315 s
# Copying data from host to device...0.002646 s
# Launching kernel...0.000228 s
# Verifying results...TEST PASSED

# %%
# !./histogram 50000 1024
# Out:
# Setting up the problem...0.001025 s
#     Input size = 50000
#     Number of bins = 1024
# Allocating device variables...0.195822 s
# Copying data from host to device...0.000261 s
# Launching kernel...0.000180 s
# Verifying results...TEST PASSED
